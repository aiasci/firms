# %%
## Required Libraries
import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
## Required Code due to errors occured
from selenium.common.exceptions import UnexpectedAlertPresentException
## path for chrome-driver of selenium
path = '/home/ismetovic/Downloads/chromedriver' 
options = Options()
options.headless = False
## opening the driver
driver = webdriver.Chrome(options=options, executable_path=path)
## opening the website
driver.get('https://www.bddk.org.tr/bultenaylik')

# %%
## key for dropdown menu of years
key_for_year = list(range(2002,2022))
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div"))).click()
key_year = len(WebDriverWait(driver, 20).until(EC.visibility_of_all_elements_located((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li")))) + 1
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[1]/div/div"))).click()
## key for dropdown menu of months
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
key_month = len(WebDriverWait(driver, 20).until(EC.visibility_of_all_elements_located((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li")))) + 1
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[1]/div/div"))).click()

# %%
## Creating empty DataFrame
datum = pd.DataFrame()

# %%
###########################
# BDDK or BRSA started to collect data from banks after December 2002. For easement I started scrap the that year alone while creating loops for other years. 
# Also, sectoral distribution of the data requires another loop. 
###########################
## Calling the Year 2002
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[20]"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Calling the Last Month of the year
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]")))
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Clicking the create the report button
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Saving the table as DataFrame
df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
## İnserting Month Columns
df.insert(0,'Month',12)
## İnserting Year Columns
df.insert(0, 'Year', key_for_year[0])
## İnserting Sector Columns
df.insert(0, 'Type', "Sektör")
## Choosing required area
df = df.iloc[2:,:8]
## Appending the DataFrames
datum =datum.append(df)

# %%
## Loop for Years upto 2020
for i in range(1,key_year-2):
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
## Loop for Months
    for j in range(1, key_month):
        try:
            key_for_year1 = key_for_year[i]
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Data Manipulation
            df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
            df.insert(0,'Month',j)
            df.insert(0, 'Year', key_for_year1)
            df.insert(0, 'Type', "Sektör")
            df = df.iloc[2:,:8]
            datum = datum.append(df)
        except UnexpectedAlertPresentException:
            continue
## Loop for 2021
for i in range(key_year-2,key_year-1):
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
## Loop for First 7 Months of 2021
    for j in range(1, key_month-5):
        try:
            key_for_year1 = key_for_year[i]
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Data Manipulation
            df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
            df.insert(0,'Month',j)
            df.insert(0, 'Year', key_for_year1)
            df.insert(0, 'Type', "Sektör")
            df = df.iloc[2:,:8]
            datum = datum.append(df)
        except UnexpectedAlertPresentException:
            continue     
driver.quit()

# %%
#################
# Because of the high RAM usage and loading problems for every bank type, driver restarts.
#################

## Bank types
type_list = ["Katılım","Kalkınma ve Yatırım","Yerli Özel","Kamu","Yabancı"]
## Loop for Bank Types
for k in list(range(7,12)):
## Opening the driver and website
    driver = webdriver.Chrome(options=options, executable_path=path)
    driver.get('https://www.bddk.org.tr/bultenaylik')
## December 2002
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))  
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/div"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/div/ul/li[1]/a"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[2]/div/div[1]/div/div/ul/li[{k}]"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[20]"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]")))
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Data Manipulation
    df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
    df.insert(0,'Month',j)
    df.insert(0, 'Year', key_for_year[0])
    df.insert(0, 'Type', type_list[k-7])
    df = df.iloc[2:,:8]
    datum = datum.append(df)
## Loop for Years upto 2020
    for i in range(1,key_year-2):
        WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
## Loop for Months
        for j in range(1, key_month):
            try:
                key_for_year1 = key_for_year[i]
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Data Manipulation
                df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
                df.insert(0,'Month',j)
                df.insert(0, 'Year', key_for_year1)
                df.insert(0, 'Type', type_list[k-7])
                df = df.iloc[2:,:8]
                datum = datum.append(df)
            except UnexpectedAlertPresentException:
                continue
## Loop for 2021
    for i in range(key_year-2,key_year-1):
        WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
## Loop for First 7 Months of 2021
        for j in range(1, key_month-5):
            try:
                key_for_year1 = key_for_year[i]
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
## Data Manipulation
                df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
                df.insert(0,'Month',j)
                df.insert(0, 'Year', key_for_year1)
                df.insert(0, 'Type', type_list[k-7])
                df = df.iloc[2:,:8]
                datum = datum.append(df)
            except UnexpectedAlertPresentException:
                continue
    driver.quit()

# %%
## Renaming Columns
datum.columns = ["Type","Year","Month","n","code","TL","YP","Total"]
## Saving it as XLSX
datum.to_excel("datum_balance.xlsx", sheet_name = "Sheet 1")

# %%
## Opening the driver
driver = webdriver.Chrome(options=options, executable_path=path)
## Opening the website
driver.get('https://www.bddk.org.tr/bultenaylik')
## Clicking the Profit section
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/table/tbody/tr[2]/td"))).click()
## Re-creating the DataFrame
datum = pd.DataFrame()
##############
# Rest of the code follows same same structure. Only exception is after restarting the driver, profir section is clicked.
##############

# %%
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[20]"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))

WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]")))
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
df.insert(0,'Month',12)
df.insert(0, 'Year', key_for_year[0])
df.insert(0, 'Type', "Sektör")
df = df.iloc[2:,:8]
datum =datum.append(df)

# %%
for i in range(1,key_year-2):
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
    for j in range(1, key_month):
        try:
            key_for_year1 = key_for_year[i]
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
            df.insert(0,'Month',12)
            df.insert(0, 'Year', key_for_year1)
            df.insert(0, 'Type', "Sektör")
            df = df.iloc[2:,:8]
            datum = datum.append(df)
        except UnexpectedAlertPresentException:
            continue
for i in range(key_year-2,key_year-1):
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
    for j in range(1, key_month-5):
        try:
            key_for_year1 = key_for_year[i]
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
            WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
            df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
            df.insert(0,'Month',j)
            df.insert(0, 'Year', key_for_year1)
            df.insert(0, 'Type', "Sektör")
            df = df.iloc[2:,:8]
            datum = datum.append(df)
        except UnexpectedAlertPresentException:
            continue     
driver.quit()

# %%
for k in list(range(7,12)):
    driver = webdriver.Chrome(options=options, executable_path=path)
    driver.get('https://www.bddk.org.tr/bultenaylik')
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/table/tbody/tr[2]/td"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))  
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/div"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/div/ul/li[1]/a"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[2]/div/div[1]/div/div/ul/li[{k}]"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[20]"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]")))
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[12]"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
    WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
    df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
    df.insert(0,'Month',j)
    df.insert(0, 'Year', key_for_year[0])
    df.insert(0, 'Type', type_list[k-7])
    df = df.iloc[2:,:8]
    datum = datum.append(df)
    for i in range(1,key_year-2):
        WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
        for j in range(1, key_month):
            try:
                key_for_year1 = key_for_year[i]
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
                df.insert(0,'Month',j)
                df.insert(0, 'Year', key_for_year1)
                df.insert(0, 'Type', type_list[k-7])
                df = df.iloc[2:,:8]
                datum = datum.append(df)
            except UnexpectedAlertPresentException:
                continue
    for i in range(key_year-2,key_year-1):
        WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[1]/a/div/b"))).click()
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[1]/div/ul/li[{key_year-i-1}]"))).click()
        for j in range(1, key_month-5):
            try:
                key_for_year1 = key_for_year[i]
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[1]/div/div[2]/a/div/b"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]")))
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div[5]/div/div[3]/div[1]/div/div[2]/div/ul/li[{j}]"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[5]/div/div[3]/div[2]/div/div[1]/button"))).click()
                WebDriverWait(driver, 20).until(EC.invisibility_of_element((By.XPATH, "/html/body/div[6]/div/i")))
                df = pd.read_html(driver.find_element_by_xpath("//*[@id='grdRapor']").get_attribute('outerHTML'))[0]
                df.insert(0,'Month',j)
                df.insert(0, 'Year', key_for_year1)
                df.insert(0, 'Type', type_list[k-7])
                df = df.iloc[2:,:8]
                datum = datum.append(df)
            except UnexpectedAlertPresentException:
                continue
    driver.quit()

# %%
datum.columns = ["Type","Year","Month","n","code","TL","YP","Total"]
datum
datum.to_excel("/datum_profits.xlsx", sheet_name = "Sheet 1")
