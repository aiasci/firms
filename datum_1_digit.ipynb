# %%
 # Required libraries
import numpy as np
import pandas as pd
import string as st

# %%
# Main DataFrame for manipulatiion
datum = pd.read_excel("https://github.com/aiasci/firms/blob/main/df_1_digit.xlsx?raw=true")
datum.index = list(datum.iloc[:,0])

# %%
key_column =  list(range(3,14))
x1 = 257
x2 = 246
key_row = list(range(1,len(datum.loc[datum["n"]==x1])))
key_row_2 = list(range(1,len(datum.loc[datum["n"]==x2])))

# %%
datum.loc[datum["n"]==1]
# Out:
#                                                                             Unnamed: 0  \
# A-Agriculture, forestry and fishing LARGE    A-Agriculture, forestry and fishing LARGE
# A-Agriculture, forestry and fishing MEDIUM  A-Agriculture, forestry and fishing MEDIUM
# A-Agriculture, forestry and fishing MICRO    A-Agriculture, forestry and fishing MICRO
# A-Agriculture, forestry and fishing SMALL    A-Agriculture, forestry and fishing SMALL
# B-Mining and quarrying LARGE                              B-Mining and quarrying LARGE
# ...                                                                                ...
# R-Arts, entertainment and recreation MICRO  R-Arts, entertainment and recreation MICRO
# R-Arts, entertainment and recreation SMALL  R-Arts, entertainment and recreation SMALL
# S-Other services activities MEDIUM                  S-Other services activities MEDIUM
# S-Other services activities MICRO                    S-Other services activities MICRO
# ...
